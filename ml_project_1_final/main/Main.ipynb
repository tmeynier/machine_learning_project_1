# %% [markdown]
# # This is a main notebook to run the code we have made
#
# This is a main notebook to run the code we have made

# %% [markdown]
# ## Samples visualisation and clustering

# %% [markdown]
# For the Arrhythmia Dataset

# %%
# %run ../plot/tsne_mit.py

# %% [markdown]
# For the PTB Diagnostic ECG Database

# %%
# %run ../plot/tsne_ptb.py

# %% [markdown]
# ## Predictions using RNNs for both data set

# %% [markdown]
# For the Arrhythmia Dataset

# %%
# %run ../rnn/RNN_mitbih.py
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# simple_rnn_1 (SimpleRNN)     (None, 187, 256)          66048
# _________________________________________________________________
# simple_rnn_2 (SimpleRNN)     (None, 124)               47244
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 625
# ...
# Total params: 113,917
# Trainable params: 113,917
# Non-trainable params: 0
# _________________________________________________________________
# Train on 78798 samples, validate on 8756 samples
# Epoch 1/1000
#  - 94s - loss: 0.4420 - acc: 0.8774 - val_loss: 0.3284 - val_acc: 0.9148
#
# Epoch 00001: val_acc improved from -inf to 0.91480, saving model to rnn_mitbih.h5
# Epoch 2/1000
#  - 94s - loss: 0.3266 - acc: 0.9125 - val_loss: 0.2832 - val_acc: 0.9239
#
# ...

# %% [markdown]
# For the PTB Diagnostic ECG Database

# %%
# %run ../rnn/RNN_ptbdb.py
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# simple_rnn_1 (SimpleRNN)     (None, 187, 128)          16640
# _________________________________________________________________
# simple_rnn_2 (SimpleRNN)     (None, 64)                12352
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# ...
# Total params: 29,057
# Trainable params: 29,057
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10476 samples, validate on 1165 samples
# Epoch 1/1000
#  - 10s - loss: 0.5836 - acc: 0.7176 - val_loss: 0.5692 - val_acc: 0.7082
#
# Epoch 00001: val_acc improved from -inf to 0.70815, saving model to rnn_ptbdb.h5
# Epoch 2/1000
#  - 9s - loss: 0.5392 - acc: 0.7264 - val_loss: 0.5566 - val_acc: 0.7064
#
# Epoch 00002: val_acc did not improve from 0.70815
# ...

# %% [markdown]
# ## Standard model : SVM

# %% [markdown]
# 1-Considering each point as a feature vector

# %% [markdown]
# a-For the PTB Dataset

# %%
# %run ../svm/svm_187_features_ptb.py
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   23.9s remaining:   35.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   24.9s finished
# Accuracy: 0.940227
# Precision: 0.979125
# Recall: 0.937203
# F1 score: 0.957705
# Test auroc score : 0.942643359258767
# Test auprc score : 0.9629840336037621

# %% [markdown]
# b-For the MIT Dataset

# %%
# %run ../svm/svm_187_features_mit.py
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 20.6min remaining: 30.9min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 21.4min finished
# Accuracy: 0.943906
# Precision: 0.965093
# Recall: 0.943906
# F1 score: 0.951639

# %% [markdown]
# 2-With Feature extraction

# %% [markdown]
# a-For the PTB Dataset

# %%
# %run ../svm/svm_20_features_ptb.py
# Out:
# Using TensorFlow backend.
# /cluster/apps/python/3.7.4/x86_64/lib64/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /cluster/apps/python/3.7.4/x86_64/lib64/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   42.4s finished
# Accuracy: 0.817588
# Precision: 0.953784
# Recall: 0.785442
# F1 score: 0.861466
# Test auroc score : 0.8432774601621388
# Test auprc score : 0.9040719584383712

# %% [markdown]
# b-For the MIT Dataset

# %%
# %run ../svm/svm_20_features_mit.py
# Out:
# /cluster/apps/python/3.7.4/x86_64/lib64/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /cluster/apps/python/3.7.4/x86_64/lib64/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  8.8min remaining: 13.2min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  9.1min finished
# Accuracy: 0.779006
# Precision: 0.923705
# Recall: 0.779006
# F1 score: 0.830253

# %% [markdown]
# ## Bidirectional RNN

# %% [markdown]
# For the Arrhythmia Dataset

# %%
# %run ../rnn_bi/RNNbi_mitbih.py

# %% [markdown]
# For the PTB Diagnostic ECG Database

# %%
# %run ../rnn_bi/RNNbi_ptbdb.py

# %% [markdown]
# ## CNN With residual blocks

# %% [markdown]
# For the Arrhythmia Dataset

# %% [markdown]
# a-Using padding = "same"

# %%
# %run ../residual_network/residual_blocks_mit.py
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 187, 1)       0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 183, 32)      192         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 183, 32)      5152        conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 183, 32)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 183, 32)      5152        activation_1[0][0]
# ...

# %% [markdown]
# b-Using padding = "causal"

# %%
# %run ../residual_network/residual_blocks_mit_causal.py
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 187, 1)       0
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 183, 32)      192         input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 183, 32)      5152        conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 183, 32)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 183, 32)      5152        activation_12[0][0]
# ...

# %% [markdown]
# For the PTB Diagnostic ECG Database

# %% [markdown]
# a-Using padding = "same"

# %%
# %run ../residual_network/residual_blocks_ptbdb.py
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            (None, 187, 1)       0
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 183, 32)      192         input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 183, 32)      5152        conv1d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 183, 32)      0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 183, 32)      5152        activation_23[0][0]
# ...

# %% [markdown]
# b-Using padding = "causal"

# %%
# %run ../residual_network/residual_blocks_ptbdb_causal.py
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            (None, 187, 1)       0
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 183, 32)      192         input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 183, 32)      5152        conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 183, 32)      0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 183, 32)      5152        activation_35[0][0]
# ...

# %% [markdown]
# ## Ensemble of models

# %% [markdown]
# For the Arrhythmia Dataset

# %% [markdown]
# a-Using mode

# %%
# %run ../ensemble_method/nn_ensemble_method_mode_mitbih.py ../rnn/rnn_mitbih.h5 ../rnn_bi/rnn_bi_mitbih.h5 ../residual_network/resnet_mitbih_causal.h5
# Out:
# Accuracy: 0.986570
# Precision: 0.986320
# Recall: 0.986570
# F1 score: 0.986125

# %% [markdown]
# b-Using softmax

# %%
# %run ../ensemble_method/nn_ensemble_method_softmax_mitbih.py ../rnn/rnn_mitbih.h5 ../rnn_bi/rnn_bi_mitbih.h5 ../residual_network/resnet_mitbih_causal.h5
# Out:
# Accuracy: 0.987119
# Precision: 0.986857
# Recall: 0.987119
# F1 score: 0.986662

# %% [markdown]
# For the PTB Diagnostic ECG Database

# %% [markdown]
# a-Using Mode

# %%
# %run ../ensemble_method/nn_ensemble_method_mode_ptbdb.py ../rnn/rnn_ptbdb.h5 ../rnn_bi/rnn_bi_ptbdb.h5 ../residual_network/resnet_ptbdb_causal.h5
# Out:
# Accuracy: 0.969283
# Precision: 0.960113
# Recall: 0.998953
# F1 score: 0.979148
# Test auroc score : 0.9455961139452925
# Test auprc score : 0.9598640899913585

# %% [markdown]
# b-Using softmax

# %%
# %run ../ensemble_method/nn_ensemble_method_softmax_ptbdb.py ../rnn/rnn_ptbdb.h5 ../rnn_bi/rnn_bi_ptbdb.h5 ../residual_network/resnet_ptbdb_causal.h5
# Out:
# Accuracy: 0.989211
# Precision: 0.986554
# Recall: 0.998667
# F1 score: 0.992574
# Test auroc score : 0.9816619394759616
# Test auprc score : 0.9862012448795122

# %% [markdown]
# ## Transfer Learning

# %% [markdown]
# 1-Transfer learning with RNNs, frozen base model.

# %%
# %run ../transfer_learning/transfer_learning1.py
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_5 (InputLayer)         (None, 124)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 124)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 125
# ...
# Total params: 125
# Trainable params: 125
# Non-trainable params: 0
# _________________________________________________________________
# Train on 10476 samples, validate on 1165 samples
# Epoch 1/1000
#  - 0s - loss: 0.6662 - acc: 0.6034 - val_loss: 0.6201 - val_acc: 0.6455
#
# Epoch 00001: val_acc improved from -inf to 0.64549, saving model to transfert_learning1.h5
# Epoch 2/1000
#  - 0s - loss: 0.6087 - acc: 0.6722 - val_loss: 0.5885 - val_acc: 0.6764
#
# ...

# %% [markdown]
# 2-Transfer learning with RNNs, retraining whole model.

# %%
# %run ../transfer_learning/transfer_learning2.py
# Out:
# /cluster/home/mchevalley/ml_project1/transfer_learning/transfer_learning2.py:24: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("de...)`
#   model2 = Model(inputs = new_model.inputs, output = dense_1)
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# simple_rnn_1_input (InputLay (None, 187, 1)            0
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 187, 256)          66048
# _________________________________________________________________
# simple_rnn_2 (SimpleRNN)     (None, 124)               47244
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 124)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 125
# ...

# %% [markdown]
# 3-Transfer learning with RNNs, first frozen base model,

# %%
# %run ../transfer_learning/transfer_learning3.py
# Out:
# /cluster/home/mchevalley/ml_project1/transfer_learning/transfer_learning3.py:25: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("de...)`
#   frozen_model = Model(inputs = new_model.inputs, output = layer)
# Train on 10476 samples, validate on 1165 samples
# Epoch 1/1000
#  - 9s - loss: 0.5081 - acc: 0.7312 - val_loss: 0.4973 - val_acc: 0.7631
#
# Epoch 00001: val_acc improved from -inf to 0.76309, saving model to transfert_learning3.h5
# Epoch 2/1000
#  - 9s - loss: 0.4614 - acc: 0.7794 - val_loss: 0.4872 - val_acc: 0.7614
#
# Epoch 00002: val_acc did not improve from 0.76309
# Epoch 3/1000
#  - 9s - loss: 0.4540 - acc: 0.7819 - val_loss: 0.4858 - val_acc: 0.7648
#
# Epoch 00003: val_acc improved from 0.76309 to 0.76481, saving model to transfert_learning3.h5
# Epoch 4/1000
#  - 9s - loss: 0.4499 - acc: 0.7874 - val_loss: 0.4812 - val_acc: 0.7639
#
# Epoch 00004: val_acc did not improve from 0.76481
# Epoch 5/1000
# ...
